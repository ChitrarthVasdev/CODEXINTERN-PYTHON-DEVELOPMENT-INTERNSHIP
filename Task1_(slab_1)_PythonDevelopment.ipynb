# %% [markdown]
# <a href="https://colab.research.google.com/github/ChitrarthVasdev/CODEXINTERN-PYTHON-DEVELOPMENT-INTERNSHIP/blob/main/Task1_(slab_1)_PythonDevelopment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TASK 1 (SLAB 1) PYTHON DEVELOPMENT INTERNSHIP
#
# # LANGUAGE : PYTHON

# %%
# Step 1: Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 2: Load your uploaded dataset
df = pd.read_csv('/content/advertising.csv')

# Step 3: Display dataset info
print("📊 First 5 rows of the dataset:")
print(df.head())

print("\n📈 Dataset Summary:")
print(df.describe())

print("\n🔢 Columns:")
print(df.columns.tolist())
# Out:
# 📊 First 5 rows of the dataset:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9
#
# 📈 Dataset Summary:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000
#
# 🔢 Columns:
# ['TV', 'Radio', 'Newspaper', 'Sales']

# %%
# Choose a numeric column for average
average_sales = df['Sales'].mean()
print(f"\n✅ Average Sales: {average_sales:.2f}")
# Out:
# ✅ Average Sales: 15.13

# %%
# Average Spend per Channel
df[['TV', 'Radio', 'Newspaper']].mean().plot(kind='bar', color=['red', 'blue', 'green'])
plt.title("Average Advertising Spend by Channel")
plt.ylabel("Average Spend")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# TV Spend vs Sales
sns.scatterplot(data=df, x='TV', y='Sales', color='purple')
plt.title("TV Spend vs Sales")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()
